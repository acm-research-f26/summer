# %% [markdown]
# # Dashboard Visualization Tutorial
#
# This notebook demonstrates interactive visualization of preprocessed EEG data including:
# - Signal quality overview
# - Frequency domain analysis
# - Channel comparison

# %%
import numpy as np
import mne
from sleepeegpy.preprocessing import dashboard
from sleepeegpy.visualization import dashboard_plots

# Load preprocessed data
# raw = mne.io.read_raw_fif('preprocessed_data.fif')

# %%
# Create quality overview
# dashboard_plots.plot_signal_quality(raw)

# %%
# Plot power spectral density for all channels
# dashboard_plots.plot_psd_overview(raw)

# %%
# Plot channel statistics
# dashboard_plots.plot_channel_stats(raw)
