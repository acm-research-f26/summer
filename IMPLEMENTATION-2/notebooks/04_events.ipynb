# %% [markdown]
# # Sleep Event Detection Tutorial
#
# This notebook demonstrates detection of sleep-related events:
# - Sleep spindles
# - Slow waves
# - Rapid Eye Movements (REMs)

# %%
import numpy as np
import mne
from sleepeegpy.analysis import events
from sleepeegpy.visualization import event_plots

# Load preprocessed EEG data
# raw = mne.io.read_raw_fif('preprocessed_data.fif')

# %%
# Detect sleep spindles
# spindles = events.detect_spindles(raw, ch_names=['C3', 'C4'])

# %%
# Detect slow waves
# slow_waves = events.detect_slow_waves(raw, ch_names=['F3', 'F4', 'C3', 'C4'])

# %%
# Detect REMs
# rems = events.detect_rems(raw, ch_names=['EOG1', 'EOG2'])

# %%
# Visualize detected events
# event_plots.plot_events(raw, spindles=spindles, slow_waves=slow_waves)
