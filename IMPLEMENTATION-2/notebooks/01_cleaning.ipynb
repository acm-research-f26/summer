# %% [markdown]
# # EEG Cleaning Tutorial
#
# This notebook demonstrates the basic cleaning operations for EEG data including:
# - Resampling
# - Filtering
# - Bad channel detection and rejection
# - Bad epoch detection and rejection

# %%
import numpy as np
import mne
from sleepeegpy.preprocessing import cleaning

# Load sample EEG data
# raw = mne.io.read_raw_fif('sample_data.fif')

# %%
# Resample to 100 Hz
# raw.resample(100)

# %%
# Apply bandpass filter (0.5 - 30 Hz)
# raw.filter(0.5, 30)

# %%
# Identify and remove bad channels
# raw.info['bads'] = ['A1', 'A2']

# %%
# Detect and remove bad epochs
# bad_epochs = cleaning.detect_bad_epochs(raw)
