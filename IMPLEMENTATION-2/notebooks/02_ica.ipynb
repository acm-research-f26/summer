# %% [markdown]
# # ICA Decomposition and Component Rejection Tutorial
#
# This notebook demonstrates:
# - Independent Component Analysis (ICA) decomposition
# - Automatic artifact component detection
# - Manual component rejection

# %%
import numpy as np
import mne
from sleepeegpy.preprocessing import ica

# Load cleaned EEG data
# raw = mne.io.read_raw_fif('cleaned_data.fif')

# %%
# Fit ICA decomposition
# ica_model = ica.fit_ica(raw, method='infomax', n_components=30)

# %%
# Identify artifact components automatically
# artifact_components = ica.detect_artifact_components(ica_model, raw)

# %%
# Exclude artifact components
# ica_model.exclude = artifact_components
# raw_ica = ica_model.apply(raw)

# %%
# Plot components for manual inspection
# ica_model.plot_components()
