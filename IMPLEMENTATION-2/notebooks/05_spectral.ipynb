# %% [markdown]
# # Spectral Analysis Tutorial
#
# This notebook demonstrates spectral analysis of EEG signals:
# - Power Spectral Density (PSD) computation
# - Frequency band extraction
# - SpecParam parametrization

# %%
import numpy as np
import mne
from sleepeegpy.analysis import spectral
from sleepeegpy.visualization import spectrogram

# Load preprocessed EEG data
# raw = mne.io.read_raw_fif('preprocessed_data.fif')

# %%
# Compute PSD
# analyzer = spectral.SpectralAnalyzer(raw.info['sfreq'])
# psd_results = analyzer.analyze(raw.get_data())

# %%
# Extract band powers
# band_powers = psd_results['band_powers']
# print(band_powers)

# %%
# Plot spectrogram
# spectrogram.plot_spectrogram(raw)

# %%
# Plot PSD with frequency bands
# spectrogram.plot_psd_bands(psd_results['freqs'], psd_results['psd'])
