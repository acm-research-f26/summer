# %%
import pickle
from gameKeyFunctions import resetGame, RunGame, Tree, Node, NodeType

fileNames = ["best_tree_0.pkl", "best_tree_1.pkl", "best_tree_2.pkl"]

print("uh")
for name in fileNames:
    print("dawg what")
    game = resetGame(True)
    print("a")
    with open(name, "rb") as f:
        tree = pickle.load(f)
        print(type(tree))
        print(tree)
        print("Gay")
        RunGame(tree, game, 1)
        f.close()
# Out:
# uh
# dawg what
# a
# <class 'gameKeyFunctions.Tree'>
# ...
# Gay
# score so far: 0
# score so far: -25279.782304690096
# dawg what
# a
# <class 'gameKeyFunctions.Tree'>
# ...
# Gay
# score so far: 0
# score so far: -32649.641849837462
