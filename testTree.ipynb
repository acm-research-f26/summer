# %%
import pickle
from gameKeyFunctions import ShowTreeStructure, resetGame, RunGame, Tree, Node, NodeType

fileNames = ["best_tree_0.pkl", "best_tree_1.pkl", "best_tree_2.pkl"]

for name in fileNames:
    game = resetGame(True)
    with open(name, "rb") as f:
        tree = pickle.load(f)
        print(f"Tree score is : {tree.score}")
        print(type(tree))
        print(tree)
        RunGame(tree, game, 1)
        ShowTreeStructure(tree.root)
        f.close()
# Out:
# Tree score is : 6692.143344142179
# <class 'gameKeyFunctions.Tree'>
# ...
# score so far: 0
# [COND] manyEnemies?
#   T:
#     [COND] lowAmmoCurrent?
#       T:
#         [COND] armorNearby?
#           T:
#             [COND] chaingunEquipped?
#               T:
#                 [COND] mediumArmor?
#                   T:
#                     [COND] recentlyHurt?
#                       T:
#                         [ACTION] chargeIn
#                       F:
#                         [ACTION] directlyFlee
#                   F:
#                     [COND] highArmor?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] chargeIn
#               F:
#                 [COND] someRangedEnemy?
#                   T:
#                     [COND] highArmor?
#                       T:
#                         [ACTION] runAway
#                       F:
#                         [ACTION] goToArmor
# ...
