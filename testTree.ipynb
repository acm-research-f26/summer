# %%
import pickle
from gameKeyFunctions import ShowTreeStructure, resetGame, RunGame, Tree, Node, NodeType

fileNames = ["best_tree_0.pkl", "best_tree_1.pkl", "best_tree_2.pkl"]

print("uh")
for name in fileNames:
    print("dawg what")
    game = resetGame(True)
    print("a")
    with open(name, "rb") as f:
        tree = pickle.load(f)
        print(type(tree))
        print(tree)
        print("Gay")
        RunGame(tree, game, 1)
        ShowTreeStructure(tree.root)
        f.close()
# Out:
# uh
# dawg what
# a
# <class 'gameKeyFunctions.Tree'>
# <gameKeyFunctions.Tree object at 0x0000020B917496A0>
# Gay
# score so far: 0
# [COND] chaingunEquipped?
#   T:
#     [COND] lowAmmoCurrent?
#       T:
#         [COND] highHealth?
#           T:
#             [COND] armorNearby?
#               T:
#                 [COND] lowHealth?
#                   T:
#                     [COND] manyEnemies?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] fireAndStrafe
#                   F:
#                     [COND] lowTimeRemaining?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] fireAndStrafe
#               F:
#                 [COND] healthNearby?
#                   T:
#                     [COND] highArmor?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] directlyFlee
#                   F:
#                     [COND] someRangedEnemy?
#                       T:
#                         [ACTION] goToHealth
#                       F:
#                         [ACTION] goToAmmo
#           F:
#             [COND] ammo3Nearby?
#               T:
#                 [COND] lowHealth?
#                   T:
#                     [COND] ammo4Nearby?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] chargeIn
#                   F:
#                     [COND] noEnemies?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] switchWeapon
#               F:
#                 [COND] mediumArmor?
#                   T:
#                     [COND] manyEnemies?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] goToHealth
#                   F:
#                     [COND] mediumHealth?
#                       T:
#                         [ACTION] moveRandom
#                       F:
#                         [ACTION] directlyFlee
#       F:
#         [ACTION] switchWeapon
#   F:
#     [COND] mediumArmor?
#       T:
#         [COND] manyEnemies?
#           T:
#             [COND] mediumHealth?
#               T:
#                 [COND] highArmor?
#                   T:
#                     [COND] lowAmmoCurrent?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] directlyFlee
#                   F:
#                     [COND] lowAmmoCurrent?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] fireAndStrafe
#               F:
#                 [COND] nearbyEnemy?
#                   T:
#                     [ACTION] fireAndStrafe
#                   F:
#                     [COND] ammo3Nearby?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] switchWeapon
#           F:
#             [ACTION] directlyFlee
#       F:
#         [COND] recentlyHurt?
#           T:
#             [COND] lowAmmoCurrent?
#               T:
#                 [COND] lowHealth?
#                   T:
#                     [COND] manyEnemies?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] runAway
#                   F:
#                     [COND] lowTimeRemaining?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] fireAndStrafe
#               F:
#                 [COND] noEnemies?
#                   T:
#                     [COND] highArmor?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] goToArmor
#                   F:
#                     [COND] mediumHealth?
#                       T:
#                         [ACTION] goToHealth
#                       F:
#                         [ACTION] goToHealth
#           F:
#             [COND] lowTimeRemaining?
#               T:
#                 [COND] ammo4Nearby?
#                   T:
#                     [COND] ammo3Nearby?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] runAway
#                   F:
#                     [COND] nearbyEnemy?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] chargeIn
#               F:
#                 [COND] mediumHealth?
#                   T:
#                     [COND] someRangedEnemy?
#                       T:
#                         [ACTION] moveRandom
#                       F:
#                         [ACTION] switchWeapon
#                   F:
#                     [COND] lowHealth?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] goToArmor
# dawg what
# a
# <class 'gameKeyFunctions.Tree'>
# <gameKeyFunctions.Tree object at 0x0000020BAFB7E490>
# Gay
# score so far: 0
# [COND] lowHealth?
#   T:
#     [COND] lowAmmoCurrent?
#       T:
#         [COND] nearbyEnemy?
#           T:
#             [COND] highArmor?
#               T:
#                 [COND] ammo4Nearby?
#                   T:
#                     [COND] ammo3Nearby?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] runAway
#                   F:
#                     [COND] someRangedEnemy?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] switchWeapon
#               F:
#                 [ACTION] goToAmmo
#           F:
#             [COND] chaingunEquipped?
#               T:
#                 [COND] mediumArmor?
#                   T:
#                     [COND] ammo3Nearby?
#                       T:
#                         [ACTION] moveRandom
#                       F:
#                         [ACTION] goToAmmo
#                   F:
#                     [COND] lowTimeRemaining?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] fireAndStrafe
#               F:
#                 [COND] lowTimeRemaining?
#                   T:
#                     [COND] healthNearby?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] switchWeapon
#                   F:
#                     [COND] ammo4Nearby?
#                       T:
#                         [COND] chaingunEquipped?
#                           T:
#                             [ACTION] goToAmmo
#                           F:
#                             [ACTION] goToAmmo
#                       F:
#                         [COND] recentlyHurt?
#                           T:
#                             [ACTION] goToArmor
#                           F:
#                             [ACTION] goToArmor
#       F:
#         [COND] highHealth?
#           T:
#             [COND] lowArmor?
#               T:
#                 [ACTION] switchWeapon
#               F:
#                 [ACTION] goToArmor
#           F:
#             [COND] recentlyHurt?
#               T:
#                 [COND] healthNearby?
#                   T:
#                     [COND] manyEnemies?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] runAway
#                   F:
#                     [COND] nearbyEnemy?
#                       T:
#                         [ACTION] goToAmmo
#                       F:
#                         [ACTION] goToArmor
#               F:
#                 [COND] healthNearby?
#                   T:
#                     [COND] someRangedEnemy?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] moveRandom
#                   F:
#                     [COND] mediumHealth?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] runAway
#   F:
#     [COND] lowArmor?
#       T:
#         [COND] recentlyHurt?
#           T:
#             [ACTION] goToAmmo
#           F:
#             [COND] noEnemies?
#               T:
#                 [COND] lowTimeRemaining?
#                   T:
#                     [COND] healthNearby?
#                       T:
#                         [ACTION] chargeIn
#                       F:
#                         [ACTION] moveRandom
#                   F:
#                     [ACTION] chargeIn
#               F:
#                 [COND] manyEnemies?
#                   T:
#                     [COND] chaingunEquipped?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] runAway
#                   F:
#                     [COND] lowAmmoCurrent?
#                       T:
#                         [ACTION] goToAmmo
#                       F:
#                         [ACTION] goToArmor
#       F:
#         [ACTION] goToHealth
# dawg what
# a
# <class 'gameKeyFunctions.Tree'>
# <gameKeyFunctions.Tree object at 0x0000020BAFBD8050>
# Gay
# score so far: 0
# [COND] recentlyHurt?
#   T:
#     [COND] lowArmor?
#       T:
#         [ACTION] chargeIn
#       F:
#         [COND] ammo4Nearby?
#           T:
#             [COND] someRangedEnemy?
#               T:
#                 [COND] mediumArmor?
#                   T:
#                     [COND] armorNearby?
#                       T:
#                         [ACTION] goToAmmo
#                       F:
#                         [ACTION] switchWeapon
#                   F:
#                     [COND] armorNearby?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] goToAmmo
#               F:
#                 [COND] mediumArmor?
#                   T:
#                     [COND] lowTimeRemaining?
#                       T:
#                         [ACTION] goToHealth
#                       F:
#                         [ACTION] switchWeapon
#                   F:
#                     [COND] armorNearby?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] goToHealth
#           F:
#             [ACTION] goToHealth
#   F:
#     [COND] lowHealth?
#       T:
#         [COND] armorNearby?
#           T:
#             [COND] highArmor?
#               T:
#                 [COND] manyEnemies?
#                   T:
#                     [COND] ammo4Nearby?
#                       T:
#                         [ACTION] chargeIn
#                       F:
#                         [ACTION] goToArmor
#                   F:
#                     [COND] ammo4Nearby?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] goToArmor
#               F:
#                 [COND] nearbyEnemy?
#                   T:
#                     [COND] healthNearby?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] goToHealth
#                   F:
#                     [ACTION] goToHealth
#           F:
#             [COND] highHealth?
#               T:
#                 [COND] mediumHealth?
#                   T:
#                     [COND] chaingunEquipped?
#                       T:
#                         [ACTION] goToAmmo
#                       F:
#                         [ACTION] chargeIn
#                   F:
#                     [COND] lowArmor?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] moveRandom
#               F:
#                 [COND] lowTimeRemaining?
#                   T:
#                     [COND] mediumHealth?
#                       T:
#                         [ACTION] fireAndStrafe
#                       F:
#                         [ACTION] moveRandom
#                   F:
#                     [COND] chaingunEquipped?
#                       T:
#                         [ACTION] goToHealth
#                       F:
#                         [ACTION] moveRandom
#       F:
#         [COND] someRangedEnemy?
#           T:
#             [COND] chaingunEquipped?
#               T:
#                 [COND] manyEnemies?
#                   T:
#                     [COND] highHealth?
#                       T:
#                         [ACTION] moveRandom
#                       F:
#                         [ACTION] moveRandom
#                   F:
#                     [COND] noEnemies?
#                       T:
#                         [ACTION] goToHealth
#                       F:
#                         [ACTION] runAway
#               F:
#                 [COND] lowArmor?
#                   T:
#                     [COND] healthNearby?
#                       T:
#                         [ACTION] goToAmmo
#                       F:
#                         [ACTION] goToHealth
#                   F:
#                     [COND] ammo4Nearby?
#                       T:
#                         [ACTION] goToArmor
#                       F:
#                         [ACTION] goToAmmo
#           F:
#             [COND] noEnemies?
#               T:
#                 [COND] mediumHealth?
#                   T:
#                     [ACTION] goToArmor
#                   F:
#                     [COND] highArmor?
#                       T:
#                         [ACTION] directlyFlee
#                       F:
#                         [ACTION] goToArmor
#               F:
#                 [COND] armorNearby?
#                   T:
#                     [COND] highHealth?
#                       T:
#                         [ACTION] moveRandom
#                       F:
#                         [ACTION] moveRandom
#                   F:
#                     [COND] ammo3Nearby?
#                       T:
#                         [ACTION] switchWeapon
#                       F:
#                         [ACTION] goToArmor
